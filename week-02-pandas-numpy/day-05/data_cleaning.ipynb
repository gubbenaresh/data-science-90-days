# %%
import pandas as pd

# %%
df = pd.read_csv("employee_data_dirty.csv")

# %%
df
# Out:
#    Employee_ID    Name          Age      Department         Salary  \
# 0       EMP001   Rahul           25  Data Analytics          45000
# 1       EMP002   Priya           28              HR          52000
# 2       EMP003    Amit           24    Data Science            NaN
# 3       EMP004    Neha           30         Finance          65000
# 4       EMP005    Ravi          NaN              IT          48000
# 5       EMP006   Sneha           27  Data Analytics          55000
# 6       EMP007   Arjun           29    Data Science          60000
# 7       EMP008   Meera           26              HR          50000
# 8       EMP009   Kiran           31         Finance          72000
# 9       EMP010  Anjali           25              IT          47000
# 10      EMP010  Anjali           25              IT          47000
# 11      EMP011   Varun  twenty nine  Data Analytics          58000
# 12      EMP012   Pooja           27    Data Science          62000
# ...

# %% [markdown]
# ## Detecting & Handling Missing values

# %%
df.isnull().sum()
# Out:
# Employee_ID    0
# Name           0
# Age            1
# Department     0
# Salary         1
# Join_Date      1
# City           1
# Email          1
# Temp_Column    0
# dtype: int64

# %%
df1 = df.dropna()  # this will remove the nan values 
df1
# Out:
#    Employee_ID    Name          Age      Department         Salary  \
# 0       EMP001   Rahul           25  Data Analytics          45000
# 1       EMP002   Priya           28              HR          52000
# 3       EMP004    Neha           30         Finance          65000
# 6       EMP007   Arjun           29    Data Science          60000
# 7       EMP008   Meera           26              HR          50000
# 9       EMP010  Anjali           25              IT          47000
# 10      EMP010  Anjali           25              IT          47000
# 11      EMP011   Varun  twenty nine  Data Analytics          58000
# 12      EMP012   Pooja           27    Data Science          62000
# 13      EMP013   Rohit           32         Finance  not available
# 14      EMP014   Divya           26              HR          51000
# 15      EMP015   Manoj           23              IT          42000
# 16      EMP016  Sanjay           28  Data Analytics          57000
# ...

# %%
df1.isnull().sum()
# Out:
# Employee_ID    0
# Name           0
# Age            0
# Department     0
# Salary         0
# Join_Date      0
# City           0
# Email          0
# Temp_Column    0
# dtype: int64

# %%
# handle missing values for salary with mean value only for salary column

# df['Salary'].fillna(df['Salary'].mean())  # error because salary is in categoery type data 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Employee_ID  21 non-null     object
#  1   Name         21 non-null     object
#  2   Age          20 non-null     object
#  3   Department   21 non-null     object
#  4   Salary       20 non-null     object
#  5   Join_Date    20 non-null     object
#  6   City         20 non-null     object
#  7   Email        20 non-null     object
#  8   Temp_Column  21 non-null     int64
# dtypes: int64(1), object(8)
# memory usage: 1.6+ KB

# %%
df['Age']
# Out:
# 0              25
# 1              28
# 2              24
# 3              30
# 4             NaN
# 5              27
# 6              29
# 7              26
# 8              31
# 9              25
# 10             25
# 11    twenty nine
# 12             27
# 13             32
# 14             26
# 15             23
# 16             28
# 17             27
# 18             35
# 19             24
# 20             29
# Name: Age, dtype: object

# %%
df['Age'][11]
# Out:
# 'twenty nine'

# %%
df['Age'][11] = '29'
df['Age']
# Out:
# D:\TEMP\ipykernel_11572\2005923554.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'][11] = '29'
# 0      25
# 1      28
# 2      24
# 3      30
# 4     NaN
# 5      27
# 6      29
# 7      26
# 8      31
# 9      25
# 10     25
# 11     29
# 12     27
# 13     32
# 14     26
# 15     23
# 16     28
# 17     27
# 18     35
# 19     24
# 20     29
# Name: Age, dtype: object

# %%
# remove the entire row
df.dropna(subset='Age' , inplace=True)

# %%
df
# Out:
#    Employee_ID    Name Age      Department         Salary   Join_Date  \
# 0       EMP001   Rahul  25  Data Analytics          45000  2023-01-15
# 1       EMP002   Priya  28              HR          52000  2022-06-20
# 2       EMP003    Amit  24    Data Science            NaN  2023-03-10
# 3       EMP004    Neha  30         Finance          65000  2021-11-05
# 5       EMP006   Sneha  27  Data Analytics          55000         NaN
# 6       EMP007   Arjun  29    Data Science          60000  2022-09-18
# 7       EMP008   Meera  26              HR          50000  2023-02-28
# 8       EMP009   Kiran  31         Finance          72000  2020-08-14
# 9       EMP010  Anjali  25              IT          47000  2023-05-22
# 10      EMP010  Anjali  25              IT          47000  2023-05-22
# 11      EMP011   Varun  29  Data Analytics          58000  2022-12-01
# 12      EMP012   Pooja  27    Data Science          62000  2021-10-10
# ...

# %%
df['Age'] = pd.to_numeric(df['Age'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 0 to 20
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Employee_ID  20 non-null     object
#  1   Name         20 non-null     object
#  2   Age          20 non-null     int64
#  3   Department   20 non-null     object
#  4   Salary       19 non-null     object
#  5   Join_Date    19 non-null     object
#  6   City         19 non-null     object
#  7   Email        19 non-null     object
#  8   Temp_Column  20 non-null     int64
# dtypes: int64(2), object(7)
# memory usage: 1.6+ KB

# %%
df.isnull().sum()
# Out:
# Employee_ID    0
# Name           0
# Age            0
# Department     0
# Salary         1
# Join_Date      1
# City           1
# Email          1
# Temp_Column    0
# dtype: int64

# %%
df['Salary']
# Out:
# 0             45000
# 1             52000
# 2               NaN
# 3             65000
# 5             55000
# 6             60000
# 7             50000
# 8             72000
# 9             47000
# 10            47000
# 11            58000
# 12            62000
# 13    not available
# 14            51000
# 15            42000
# 16            57000
# 17            61000
# 18            75000
# 19            49000
# 20            53000
# Name: Salary, dtype: object

# %%
#  error='coerce' 
#  not available convert into NaN value 
# string values converted to Nan 


df['Salary'] = pd.to_numeric(df['Salary'] , errors='coerce')
df['Salary']
# Out:
# 0     45000.0
# 1     52000.0
# 2         NaN
# 3     65000.0
# 5     55000.0
# 6     60000.0
# 7     50000.0
# 8     72000.0
# 9     47000.0
# 10    47000.0
# 11    58000.0
# 12    62000.0
# 13        NaN
# 14    51000.0
# 15    42000.0
# 16    57000.0
# 17    61000.0
# 18    75000.0
# 19    49000.0
# 20    53000.0
# Name: Salary, dtype: float64

# %%
df['Salary'].fillna(df['Salary'].mean() , inplace=True)

# %%
df['Salary'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 0 to 20
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Employee_ID  20 non-null     object
#  1   Name         20 non-null     object
#  2   Age          20 non-null     int64
#  3   Department   20 non-null     object
#  4   Salary       20 non-null     float64
#  5   Join_Date    19 non-null     object
#  6   City         19 non-null     object
#  7   Email        19 non-null     object
#  8   Temp_Column  20 non-null     int64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 1.6+ KB

# %%
df.isnull().sum()
# Out:
# Employee_ID    0
# Name           0
# Age            0
# Department     0
# Salary         0
# Join_Date      1
# City           1
# Email          1
# Temp_Column    0
# dtype: int64

# %%
df.dropna(subset='Join_Date' , inplace=True)

# %%
df.Join_Date
# Out:
# 0     2023-01-15
# 1     2022-06-20
# 2     2023-03-10
# 3     2021-11-05
# 6     2022-09-18
# 7     2023-02-28
# 8     2020-08-14
# 9     2023-05-22
# 10    2023-05-22
# 11    2022-12-01
# 12    2021-10-10
# 13    2019-04-15
# 14    2023-06-30
# 15    2024-01-10
# 16    2022-02-29
# 17    2023-04-05
# 18    2020-12-18
# 19    2023-08-25
# 20    2022-07-15
# Name: Join_Date, dtype: object

# %%
df['Join_Date'] = pd.to_datetime(df['Join_Date'] , errors='coerce')

# %%
df.isnull().sum()
# Out:
# Employee_ID    0
# Name           0
# Age            0
# Department     0
# Salary         0
# Join_Date      1
# City           1
# Email          1
# Temp_Column    0
# dtype: int64

# %%
df['Join_Date'][16] = 'NaN'
# Out:
# D:\TEMP\ipykernel_11572\1794651760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Join_Date'][16] = 'NaN'

# %%
df.dropna(subset='Join_Date', inplace=True)

# %%
df['Join_Date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 0 to 20
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Employee_ID  18 non-null     object
#  1   Name         18 non-null     object
#  2   Age          18 non-null     int64
#  3   Department   18 non-null     object
#  4   Salary       18 non-null     float64
#  5   Join_Date    18 non-null     datetime64[ns]
#  6   City         17 non-null     object
#  7   Email        17 non-null     object
#  8   Temp_Column  18 non-null     int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 1.4+ KB

# %%
df.isnull().sum()
# Out:
# Employee_ID    0
# Name           0
# Age            0
# Department     0
# Salary         0
# Join_Date      0
# City           1
# Email          1
# Temp_Column    0
# dtype: int64

# %%
df['City'].fillna('Others' , inplace=True)

# %%
df.isnull().sum()
# Out:
# Employee_ID    0
# Name           0
# Age            0
# Department     0
# Salary         0
# Join_Date      0
# City           0
# Email          1
# Temp_Column    0
# dtype: int64

# %%
df['Email'].fillna('Other_email' , inplace=True)

# %%
df.isnull().sum()
# Out:
# Employee_ID    0
# Name           0
# Age            0
# Department     0
# Salary         0
# Join_Date      0
# City           0
# Email          0
# Temp_Column    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#    Employee_ID    Name  Age      Department        Salary  Join_Date  \
# 0       EMP001   Rahul   25  Data Analytics  45000.000000 2023-01-15
# 1       EMP002   Priya   28              HR  52000.000000 2022-06-20
# 2       EMP003    Amit   24    Data Science  55611.111111 2023-03-10
# 3       EMP004    Neha   30         Finance  65000.000000 2021-11-05
# 6       EMP007   Arjun   29    Data Science  60000.000000 2022-09-18
# 7       EMP008   Meera   26              HR  50000.000000 2023-02-28
# 8       EMP009   Kiran   31         Finance  72000.000000 2020-08-14
# 9       EMP010  Anjali   25              IT  47000.000000 2023-05-22
# 11      EMP011   Varun   29  Data Analytics  58000.000000 2022-12-01
# 12      EMP012   Pooja   27    Data Science  62000.000000 2021-10-10
# 13      EMP013   Rohit   32         Finance  55611.111111 2019-04-15
# 14      EMP014   Divya   26              HR  51000.000000 2023-06-30
# 15      EMP015   Manoj   23              IT  42000.000000 2024-01-10
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.reset_index(drop=True , inplace=True)

# %%
df
# Out:
#    Employee_ID    Name  Age      Department        Salary  Join_Date  \
# 0       EMP001   Rahul   25  Data Analytics  45000.000000 2023-01-15
# 1       EMP002   Priya   28              HR  52000.000000 2022-06-20
# 2       EMP003    Amit   24    Data Science  55611.111111 2023-03-10
# 3       EMP004    Neha   30         Finance  65000.000000 2021-11-05
# 4       EMP007   Arjun   29    Data Science  60000.000000 2022-09-18
# 5       EMP008   Meera   26              HR  50000.000000 2023-02-28
# 6       EMP009   Kiran   31         Finance  72000.000000 2020-08-14
# 7       EMP010  Anjali   25              IT  47000.000000 2023-05-22
# 8       EMP011   Varun   29  Data Analytics  58000.000000 2022-12-01
# 9       EMP012   Pooja   27    Data Science  62000.000000 2021-10-10
# 10      EMP013   Rohit   32         Finance  55611.111111 2019-04-15
# 11      EMP014   Divya   26              HR  51000.000000 2023-06-30
# 12      EMP015   Manoj   23              IT  42000.000000 2024-01-10
# ...
