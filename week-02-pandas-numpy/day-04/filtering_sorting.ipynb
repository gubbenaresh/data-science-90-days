# %%
import pandas as pd

# %%
df = pd.read_csv("../day-03/data/sales_data.csv")

# %%
df.head()
# Out:
#    Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0        1052  2023-02-03       Bob  North       5053.97             18
# 1        1093  2023-04-21       Bob   West       4384.02             17
# 2        1015  2023-09-21     David  South       4631.23             30
# 3        1072  2023-08-24       Bob  South       2167.94             39
# 4        1061  2023-03-24   Charlie   East       3750.20             13
#
#   Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
#
#   Payment_Method Sales_Channel Region_and_Sales_Rep
# 0           Cash        Online            North-Bob
# ...

# %%
# select the coulmns 

df['Sales_Amount']
# Out:
# 0      5053.97
# 1      4384.02
# 2      4631.23
# 3      2167.94
# 4      3750.20
#         ...
# 995    4733.88
# 996    4716.36
# 997    7629.70
# 998    1629.47
# 999    4923.93
# Name: Sales_Amount, Length: 1000, dtype: float64

# %%
# multipal columns 

df[['Product_Category','Sales_Amount']]
# Out:
#     Product_Category  Sales_Amount
# 0          Furniture       5053.97
# 1          Furniture       4384.02
# 2               Food       4631.23
# 3           Clothing       2167.94
# 4        Electronics       3750.20
# ..               ...           ...
# 995             Food       4733.88
# 996         Clothing       4716.36
# 997         Clothing       7629.70
# 998      Electronics       1629.47
# 999             Food       4923.93
#
# [1000 rows x 2 columns]

# %%
# Filter the Rows 
# one condition

df[df['Sales_Amount']>5000]
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 7          1087  2023-01-06       Eve  South       7698.92             46
# 9          1075  2023-10-09   Charlie   West       8239.58             18
# 10         1088  2023-11-16       Eve  North       8518.45             13
# 12         1024  2023-11-11       Eve   West       6607.80             21
# ..          ...         ...       ...    ...           ...            ...
# 982        1074  2023-12-16       Bob  North       6310.56             19
# 983        1039  2023-08-01       Eve   West       7527.63             36
# 989        1025  2023-12-30     David   West       9215.32             28
# 994        1068  2023-04-06     Alice  South       9093.50             31
# 997        1018  2023-04-27     David  South       7629.70             17
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
# multipal conditions

df[ (df['Sales_Amount'] > 5000) & (df['Quantity_Sold'] > 10) ]
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 7          1087  2023-01-06       Eve  South       7698.92             46
# 9          1075  2023-10-09   Charlie   West       8239.58             18
# 10         1088  2023-11-16       Eve  North       8518.45             13
# 12         1024  2023-11-11       Eve   West       6607.80             21
# ..          ...         ...       ...    ...           ...            ...
# 982        1074  2023-12-16       Bob  North       6310.56             19
# 983        1039  2023-08-01       Eve   West       7527.63             36
# 989        1025  2023-12-30     David   West       9215.32             28
# 994        1068  2023-04-06     Alice  South       9093.50             31
# 997        1018  2023-04-27     David  South       7629.70             17
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
# sorting 
df['Sales_Amount'].sort_values(ascending=True)
# Out:
# 255     100.12
# 979     106.47
# 67      113.40
# 264     114.59
# 570     119.72
#         ...
# 748    9961.96
# 654    9972.11
# 855    9972.66
# 760    9976.52
# 755    9989.04
# Name: Sales_Amount, Length: 1000, dtype: float64

# %%
df['Sales_Amount'].sort_values(ascending=False)
# Out:
# 755    9989.04
# 760    9976.52
# 855    9972.66
# 654    9972.11
# 748    9961.96
#         ...
# 570     119.72
# 264     114.59
# 67      113.40
# 979     106.47
# 255     100.12
# Name: Sales_Amount, Length: 1000, dtype: float64

# %%
# Task

# Answer at least these:

# Products with sales > ₹5,000
# Transactions with quantity > 10
# Top 10 highest-sales transactions
# Customers spending > ₹10,000
# Products sorted highest to lowest revenue

# %%
# Products with sales > ₹5,000

# df[df['Sales_Amount']>5000]['Product_Category']    # single column 
df[ df['Sales_Amount']>5000 ][['Product_Category' , 'Sales_Amount']]   # multipal columns
# Out:
#     Product_Category  Sales_Amount
# 0          Furniture       5053.97
# 7          Furniture       7698.92
# 9           Clothing       8239.58
# 10         Furniture       8518.45
# 12              Food       6607.80
# ..               ...           ...
# 982        Furniture       6310.56
# 983         Clothing       7527.63
# 989      Electronics       9215.32
# 994         Clothing       9093.50
# 997         Clothing       7629.70
#
# [501 rows x 2 columns]

# %%
# df.loc[ df['Sales_Amount'] > 5000  , 'Product_Category']  # single column 
df.loc[ df['Sales_Amount'] > 5000  , ['Product_Category' , 'Sales_Amount']  ] # multipal columns
# Out:
#     Product_Category  Sales_Amount
# 0          Furniture       5053.97
# 7          Furniture       7698.92
# 9           Clothing       8239.58
# 10         Furniture       8518.45
# 12              Food       6607.80
# ..               ...           ...
# 982        Furniture       6310.56
# 983         Clothing       7527.63
# 989      Electronics       9215.32
# 994         Clothing       9093.50
# 997         Clothing       7629.70
#
# [501 rows x 2 columns]

# %%
# Transactions with quantity > 10

df[ df['Quantity_Sold'] > 45 ][['Payment_Method','Quantity_Sold']]
# Out:
#     Payment_Method  Quantity_Sold
# 7    Bank Transfer             46
# 15            Cash             48
# 28   Bank Transfer             47
# 69            Cash             49
# 73            Cash             49
# ..             ...            ...
# 948           Cash             47
# 957           Cash             49
# 962  Bank Transfer             48
# 993    Credit Card             47
# 999           Cash             48
#
# [89 rows x 2 columns]

# %%
df.loc[ df['Quantity_Sold'] > 45 , ['Payment_Method','Quantity_Sold']]
# Out:
#     Payment_Method  Quantity_Sold
# 7    Bank Transfer             46
# 15            Cash             48
# 28   Bank Transfer             47
# 69            Cash             49
# 73            Cash             49
# ..             ...            ...
# 948           Cash             47
# 957           Cash             49
# 962  Bank Transfer             48
# 993    Credit Card             47
# 999           Cash             48
#
# [89 rows x 2 columns]

# %%
# Top 10 highest-sales transactions

df['Sales_Amount'].sort_values(ascending=False).head(10)
# Out:
# 755    9989.04
# 760    9976.52
# 855    9972.66
# 654    9972.11
# 748    9961.96
# 796    9956.75
# 142    9948.71
# 189    9933.22
# 89     9914.15
# 784    9907.72
# Name: Sales_Amount, dtype: float64

# %%
df.head()
# Out:
#    Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0        1052  2023-02-03       Bob  North       5053.97             18
# 1        1093  2023-04-21       Bob   West       4384.02             17
# 2        1015  2023-09-21     David  South       4631.23             30
# 3        1072  2023-08-24       Bob  South       2167.94             39
# 4        1061  2023-03-24   Charlie   East       3750.20             13
#
#   Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
#
#   Payment_Method Sales_Channel Region_and_Sales_Rep
# 0           Cash        Online            North-Bob
# ...

# %%
# Customers spending > ₹10,000

df[df['Sales_Amount']>7000][['Customer_Type']]
# Out:
#     Customer_Type
# 7             New
# 9             New
# 10            New
# 14            New
# 21            New
# ..            ...
# 981           New
# 983           New
# 989           New
# 994     Returning
# 997     Returning
#
# [302 rows x 1 columns]

# %%
df
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 2          1015  2023-09-21     David  South       4631.23             30
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 4          1061  2023-03-24   Charlie   East       3750.20             13
# ..          ...         ...       ...    ...           ...            ...
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 997        1018  2023-04-27     David  South       7629.70             17
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
# Products sorted highest to lowest revenue

df.sort_values('Sales_Amount' , ascending=False)[['Sales_Amount','Product_Category']]
# Out:
#      Sales_Amount Product_Category
# 755       9989.04             Food
# 760       9976.52        Furniture
# 855       9972.66         Clothing
# 654       9972.11         Clothing
# 748       9961.96        Furniture
# ..            ...              ...
# 570        119.72         Clothing
# 264        114.59             Food
# 67         113.40        Furniture
# 979        106.47         Clothing
# 255        100.12         Clothing
#
# [1000 rows x 2 columns]
