# %%
transactions = [100, 500, 1200, 300, 750, 2000, 50]

# %%
# Total transactions
# Total amount
# Average transaction
# Highest transaction
# Lowest transaction
# Transactions > 500
# Number of transactions > 500

# %%
print(len(transactions))

# or 

c=0 
for i in transactions:
    c=c+1
print(c)
# Out:
# 7
# 7

# %%
print(sum(transactions))

# or
 
s=0
for i in range(len(transactions)):
    s=s+transactions[i]
print(s)
# Out:
# 4900
# 4900

# %%
s=0
c=0
for i in range(len(transactions)):
    s=s+transactions[i]
    c=c+1
print(s)
print(c)

print(s/c)
# Out:
# 4900
# 7
# 700.0

# %%
print(max(transactions))
# Out:
# 2000

# %%
print(min(transactions))
# Out:
# 50

# %%
for i in transactions:
    if i>500:
        print(i)
# Out:
# 1200
# 750
# 2000

# %%
c=0
for i in transactions:
    if i>500:
        c=c+1
print(c)
# Out:
# 3
