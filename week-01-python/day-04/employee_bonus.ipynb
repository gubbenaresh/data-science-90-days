# %%
salary = 60000
performance = 4.5

# %%
# # 4.5 performance 

# bonus = salary * 0.20
# final_salary = salary + bonus

# print(salary)
# print(performance)
# print(bonus)
# print(final_salary)

# %%
if performance >=- 4.5:
     bonus = salary * 0.20 
     final_salary = salary + bonus
     print(bonus,"->",final_salary)
elif performance >=4.0 and performance < 4.5:
    bonus = salary * 0.15
    final_salary = salary + bonus
    print(bonus,"->",final_salary)
elif performance >= 3 and performance < 4:
    bonus = salary * 0.10
    final_salary = salary + bonus
    print(bonus,"->",final_salary)
elif performance <3:
    bonus = salary * 0.5
    final_salary = salary + bonus
    print(bonus,"->",final_salary)
else:
    print("not a valid number")
# Out:
# 12000.0 -> 72000.0
