# %%
customers = [
    {"name": "Rahul", "age": 25, "salary": 50000},
    {"name": "Priya", "age": 28, "salary": 60000},
    {"name": "Amit", "age": 30, "salary": 45000},
    {"name": "Sneha", "age": 26, "salary": 70000}
]

# %%
# Find:

# Number of customers
# Highest salary
# Lowest salary
# Average salary
# Customers earning > ₹50,000

# Don't use Pandas.

# %%
len(customers)
# Out:
# 4

# %%
max(i['salary'] for i in customers)
# Out:
# 70000

# %%
sal = [] 
for i in customers:
    sal+=[i['salary']]
print(min(sal))
# Out:
# 45000

# %%
sal = [] 
for i in customers:
    sal+=[i['salary']]
print(sum(sal)/len(sal))
# Out:
# 56250.0

# %%
sal = [] 
for i in customers:
    sal+=[i['salary']]

for i in sal:
    if i>50000:
        print(i)
# Out:
# 60000
# 70000
