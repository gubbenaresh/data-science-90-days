# %%
name = "Naresh"
age = 25
salary = 50000
is_working = True
city = "Bangalore"

print(name)
print(age)
print(salary)
print(is_working)
print(city)

print(type(name))
print(type(age))
print(type(salary))
print(type(is_working))
print(type(city))
# Out:
# Naresh
# 25
# 50000
# True
# Bangalore
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'bool'>
# <class 'str'>

# %%
# customer_name
# customer_age
# customer_salary
# customer_city
# customer_is_active

customer_name = "naresh"
customer_age = 24
customer_salary = 50000
customer_city = "Bengaluru"
customer_is_active = True 

print(customer_name)
print(customer_age)
print(customer_salary)
print(customer_city)
print(customer_is_active)

print("+"*100)

print(type(customer_name))
print(type(customer_age))
print(type(customer_salary))
print(type(customer_city))
print(type(customer_is_active))
# Out:
# naresh
# 24
# 50000
# Bengaluru
# True
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'bool'>
