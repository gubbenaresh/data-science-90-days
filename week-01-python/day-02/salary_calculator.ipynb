# %%
salary = 60000
bonus = 10000
tax = 5000

# %%
print("Total Salary:",salary+bonus+tax)
# Out:
# Total Salary: 75000

# %%
print("After Tax Salary:", salary+bonus)
# Out:
# After Tax Salary: 70000

# %%
print("Annual Salary:",salary*12)
# Out:
# Annual Salary: 720000

# %% [markdown]
# ### customer eligibility program:

# %%
# Age >= 18
# AND
# Salary >= 50000 

age = 18
salary = 56000

if age >= 18 and salary >= 50000:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# Eligible
