# %%
name = "Naresh"

print("name is string:",name)
# Out:
# name is string: Naresh

# %% [markdown]
# ### String Concatenation

# %%
first_name = "Naresh"
last_name = "Gubbe"

full_name = first_name + " " + last_name

print(full_name)
# Out:
# Naresh Gubbe

# %% [markdown]
# ### f-Strings

# %%
name = "Naresh"
age = 25

print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Naresh and I am 25 years old.

# %% [markdown]
# ### String Methods

# %%
text = "Data Science"

# %%
len(text)
# Out:
# 12

# %%
text.upper()
# Out:
# 'DATA SCIENCE'

# %%
text.lower()
# Out:
# 'data science'

# %%
text.replace("Science", "Analytics")
# Out:
# 'Data Analytics'

# %%
text.split()
# Out:
# ['Data', 'Science']
