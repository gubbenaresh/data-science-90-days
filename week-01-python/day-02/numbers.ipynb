# %%
a=10
b=20

# %%
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
print(a ** b)
# Out:
# 30
# -10
# 200
# 0.5
# 0
# 10
# 100000000000000000000

# %% [markdown]
# ### /   → division
# ### //  → floor division
# ### %   → remainder
# ### **  → power

# %% [markdown]
# ### Comparison Operators

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a >= b
# Out:
# False

# %%
a <= b
# Out:
# True

# %% [markdown]
# ### Boolean Operators

# %%
# and
# or
# not

# %%
age = 25
salary = 60000

print(age >= 18 and salary >= 50000)
# Out:
# True
